# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

pd.set_option('display.max_colwidth', None)

# %%
df_transaction_data = pd.read_csv('data/transaction_data.csv')
df_product = pd.read_csv('data/product.csv')
df_hh_demographic = pd.read_csv('data/hh_demographic.csv')
df_campaign_table = pd.read_csv('data/campaign_table.csv')
df_campaign_desc = pd.read_csv('data/campaign_desc.csv')
df_coupon = pd.read_csv('data/coupon.csv')
df_coupon_redempt = pd.read_csv('data/coupon_redempt.csv')
df_casual_data = pd.read_csv('data/causal_data.csv')

# %%
# Dữ liệu giao dịch
# Ghi nhận chi tiết từng dòng sản phẩm được mua trên hóa đơn bán lẻ của hộ gia đình

# household_key: Mã định danh duy nhất cho từng hộ gia đình
# .
# basket_id: Mã định danh duy nhất cho mỗi lần mua sắm (lần đi chợ/siêu thị)
# .
# day: Ngày diễn ra giao dịch
# .
# product_id: Mã định danh duy nhất cho từng sản phẩm
# .
# quantity: Số lượng sản phẩm mua trong giao dịch
# .
# sales_value: Số tiền nhà bán lẻ nhận được từ giao dịch bán sản phẩm (sau khi đã trừ các khoản giảm giá)
# .
# store_id: Mã định danh cửa hàng
# .
# coupon_match_disc: Khoản giảm giá do nhà bán lẻ tài trợ khớp với coupon của nhà sản xuất
# .
# coupon_disc: Khoản giảm giá từ coupon của nhà sản xuất
# .
# retail_disc: Khoản giảm giá từ chương trình thẻ thành viên/thân thiết của nhà bán lẻ
# .
# trans_time: Thời gian trong ngày diễn ra giao dịch
# .
# week_no: Tuần diễn ra giao dịch (từ tuần 1 đến tuần 102)

print(df_transaction_data["TRANS_TIME"].max())
print(df_transaction_data["TRANS_TIME"].min())

df_transaction_data.head()
# Out:
# 2359
# 0
#    household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0           2375  26984851472    1     1004906         1         1.39
# 1           2375  26984851472    1     1033142         1         0.82
# 2           2375  26984851472    1     1036325         1         0.99
# 3           2375  26984851472    1     1082185         1         1.21
# 4           2375  26984851472    1     8160430         1         1.50
#
#    STORE_ID  RETAIL_DISC  TRANS_TIME  WEEK_NO  COUPON_DISC  COUPON_MATCH_DISC
# 0       364        -0.60        1631        1          0.0                0.0
# 1       364         0.00        1631        1          0.0                0.0
# 2       364        -0.30        1631        1          0.0                0.0
# 3       364         0.00        1631        1          0.0                0.0
# 4       364        -0.39        1631        1          0.0                0.0

# %%
# Thông tin sản phẩm
# Cung cấp thông tin phân loại danh mục và thương hiệu cho từng sản phẩm

# household_key: Mã định danh duy nhất cho từng hộ gia đình
# .
# basket_id: Mã định danh duy nhất cho mỗi lần mua sắm (lần đi chợ/siêu thị)
# .
# day: Ngày diễn ra giao dịch
# .
# product_id: Mã định danh duy nhất cho từng sản phẩm
# .
# quantity: Số lượng sản phẩm mua trong giao dịch
# .
# sales_value: Số tiền nhà bán lẻ nhận được từ giao dịch bán sản phẩm (sau khi đã trừ các khoản giảm giá)
# .
# store_id: Mã định danh cửa hàng
# .
# coupon_match_disc: Khoản giảm giá do nhà bán lẻ tài trợ khớp với coupon của nhà sản xuất
# .
# coupon_disc: Khoản giảm giá từ coupon của nhà sản xuất
# .
# retail_disc: Khoản giảm giá từ chương trình thẻ thành viên/thân thiết của nhà bán lẻ
# .
# trans_time: Thời gian trong ngày diễn ra giao dịch
# .
# week_no: Tuần diễn ra giao dịch (từ tuần 1 đến tuần 102)

print(df_product["DEPARTMENT"].unique())
df_product.head()
# Out:
# ['GROCERY' 'MISC. TRANS.' 'PASTRY' 'DRUG GM' 'MEAT-PCKGD' 'SEAFOOD-PCKGD'
#  'PRODUCE' 'NUTRITION' 'DELI' 'COSMETICS' 'MEAT' 'FLORAL'
#  'TRAVEL & LEISUR' 'SEAFOOD' 'MISC SALES TRAN' 'SALAD BAR' 'KIOSK-GAS'
#  'ELECT &PLUMBING' 'GRO BAKERY' 'GM MERCH EXP' 'FROZEN GROCERY'
#  'COUP/STR & MFG' 'SPIRITS' 'GARDEN CENTER' 'TOYS' 'CHARITABLE CONT'
#  'RESTAURANT' 'RX' 'PROD-WHS SALES' 'MEAT-WHSE' 'DAIRY DELI' 'CHEF SHOPPE'
#  'HBC' 'DELI/SNACK BAR' 'PORK' 'AUTOMOTIVE' 'VIDEO RENTAL' ' '
#  'CNTRL/STORE SUP' 'HOUSEWARES' 'POSTAL CENTER' 'PHOTO' 'VIDEO'
#  'PHARMACY SUPPLY']
#    PRODUCT_ID  MANUFACTURER    DEPARTMENT     BRAND            COMMODITY_DESC  \
# 0       25671             2       GROCERY  National                  FRZN ICE
# 1       26081             2  MISC. TRANS.  National  NO COMMODITY DESCRIPTION
# 2       26093            69        PASTRY   Private                     BREAD
# 3       26190            69       GROCERY   Private      FRUIT - SHELF STABLE
# ...

# %%
# Thông tin nhân khẩu học hộ gia đình
# Chứa thông tin nhân khẩu học được mã hóa theo thứ tự logic của một bộ phận hộ gia đình trong nghiên cứu

# HOMEOWNER_DESC	Tình trạng sở hữu nhà của hộ gia đình, ví dụ nhóm thuê nhà / sở hữu nhà...
# KID_CATEGORY_DESC	Nhóm hộ gia đình theo tình trạng/số lượng trẻ em
df_hh_demographic.head()
# Out:
#   classification_1 classification_2 classification_3 HOMEOWNER_DESC  \
# 0       Age Group6                X           Level4      Homeowner
# 1       Age Group4                X           Level5      Homeowner
# 2       Age Group2                Y           Level3        Unknown
# 3       Age Group2                Y           Level6      Homeowner
# 4       Age Group4                Z           Level5      Homeowner
#
#   classification_5 classification_4 KID_CATEGORY_DESC  household_key
# 0           Group5                2      None/Unknown              1
# 1           Group5                2      None/Unknown              7
# 2           Group4                3                 1              8
# 3           Group4                4                 2             13
# 4           Group3                1      None/Unknown             16

# %%
df_hh_demographic['KID_CATEGORY_DESC'].unique()
# Out:
# array(['None/Unknown', '1', '2', '3+'], dtype=object)

# %%
# Danh sách chiến dịch gửi đến hộ gia đình
# Liệt kê các chiến dịch tiếp thị mà từng hộ gia đình đã nhận được

df_campaign_table.head()
# Out:
#   DESCRIPTION  household_key  CAMPAIGN
# 0       TypeA             17        26
# 1       TypeA             27        26
# 2       TypeA            212        26
# 3       TypeA            208        26
# 4       TypeA            192        26

# %%
# Thời gian diễn ra chiến dịch
# Quy định khoảng thời gian hiệu lực cho các chiến dịch tiếp thị

df_campaign_desc.head()
# Out:
#   DESCRIPTION  CAMPAIGN  START_DAY  END_DAY
# 0       TypeB        24        659      719
# 1       TypeC        15        547      708
# 2       TypeB        25        659      691
# 3       TypeC        20        615      685
# 4       TypeB        23        646      684

# %%
# Thông tin coupon phát hành
# Liệt kê danh sách coupon được gửi trong từng chiến dịch và các sản phẩm hợp lệ được áp dụng coupon đó

# campaign: Mã chiến dịch tương ứng
# .
# coupon_upc: Mã định danh duy nhất của coupon
# .
# product_id: Mã sản phẩm mà coupon đó có thể áp dụng đổi thưởng
# .

df_coupon.head()
# Out:
#     COUPON_UPC  PRODUCT_ID  CAMPAIGN
# 0  10000089061       27160         4
# 1  10000089064       27754         9
# 2  10000089073       28897        12
# 3  51800009050       28919        28
# 4  52100000076       28929        25

# %%
duplicates = df_coupon[df_coupon.duplicated(keep=False)]

print(duplicates)
# Out:
#          COUPON_UPC  PRODUCT_ID  CAMPAIGN
# 47      54100010032       34214        27
# 49      54100010032       34214        27
# 50      54100010032       34214        27
# 51      54100010032       34214        27
# 124     54589314175       48728        27
# 126     54589314175       48728        27
# 127     54589314187       48728        27
# 128     54589314187       48728        27
# 129     54589314187       48728        27
# 130     54589314187       48728        27
# 131     54589314175       48728        27
# 132     54589314175       48728        27
# 253     51111122081       70714        27
# 254     51111122081       70714        27
# 257     51111122081       70714        27
# 258     51111122275       70714        27
# 259     51111122275       70714        27
# 260     51111122275       70714        27
# 261     51111122275       70714        27
# 262     51111122081       70714        27
# 273     54100024932       71794        27
# ...

# %%
print(
    df_coupon.sort_values(
        by=["CAMPAIGN", "COUPON_UPC", "PRODUCT_ID"]
    )
)
# Out:
#          COUPON_UPC  PRODUCT_ID  CAMPAIGN
# 27      51111030050       32387         1
# 31      51111030050       32805         1
# 34      51111030050       33198         1
# 1578    51111030050      617450         1
# 1613    51111030050      639121         1
# 3885    51111030050      896085         1
# 4326    51111030050      916993         1
# 7460    51111030050     1037332         1
# 7891    51111030050     1056509         1
# 10341   51111030050     1198708         1
# 10441   51111030050     1225869         1
# 10711   51111030050     1303589         1
# 11010   51111030050     1405495         1
# 11248   51111030050     1546881         1
# 11533   51111030050     1692686         1
# 11920   51111030050     1846094         1
# 11930   51111030050     1853330         1
# 12228   51111030050     1976188         1
# 12365   51111030050     2037968         1
# 12731   51111030050     2403912         1
# 13092   51111030050     2991358         1
# ...

# %%
# Thực tế sử dụng coupon
# Ghi nhận các coupon thực tế đã được hộ gia đình đổi thành công khi mua hàng

# household_key: Mã hộ gia đình thực hiện đổi coupon
# .
# day: Ngày giao dịch sử dụng coupon
# .
# coupon_upc: Mã coupon được áp dụng
# .
# campaign: Mã chiến dịch tương ứng với coupon
# .
df_coupon_redempt.head()
# Out:
#    household_key  DAY   COUPON_UPC  CAMPAIGN
# 0              1  421  10000085364         8
# 1              1  421  51700010076         8
# 2              1  427  54200000033         8
# 3              1  597  10000085476        18
# 4              1  597  54200029176        18

# %%
# Thông tin quảng cáo & trưng bày tại cửa hàng

# Xác định xem sản phẩm có được xuất hiện trong tờ rơi quảng cáo tuần (weekly mailer) hoặc vị trí trưng bày đặc biệt tại cửa hàng hay không
# .

# product_id: Mã sản phẩm
# .
# store_id: Mã cửa hàng
# .
# week_no: Tuần ghi nhận hoạt động quảng cáo/trưng bày
# .
# display: Vị trí trưng bày sản phẩm tại cửa hàng (ví dụ: Front End Cap, Mid-Aisle End Cap, Rear End Cap, In-Aisle...)
# .
# mailer: Vị trí hình ảnh sản phẩm xuất hiện trên tờ rơi quảng cáo (ví dụ: Trang bìa, trang trong, vị trí ô coupon...)
# .
df_casual_data.head()
# Out:
#    PRODUCT_ID  STORE_ID  WEEK_NO display mailer
# 0       26190       286       70       0      A
# 1       26190       288       70       0      A
# 2       26190       289       70       0      A
# 3       26190       292       70       0      A
# 4       26190       293       70       0      A
